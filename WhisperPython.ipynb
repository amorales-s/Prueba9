# %% [markdown]
# <a href="https://colab.research.google.com/github/amorales-s/Prueba9/blob/main/WhisperPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nueva sección

# %%
pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-cufjb2fw
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-cufjb2fw
#   Resolved https://github.com/openai/whisper.git to commit 5c1a8c10e762bf9c29fcf6b3e40f17bc8ab09864
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 84.4 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179333 sha256=93e9551e5708e8eea5a4bdccedb806a9a5ead13936257e8e58c092294f093e0b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9823d3to/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# ...

# %%
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,442 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:11 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [988 kB]
# ...

# %% [markdown]
# ## Ejecutar el modelo

# %%
import whisper
model = whisper.load_model("medium")
result = model.transcribe("/content/Facebook.mp4")
# Out:
# /usr/local/lib/python3.8/dist-packages/whisper/transcribe.py:79: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
print(result["text"])
# Out:
#  Tres estudiantes que hoy nos ofrecen estos productos, que como dicen las profesoras desde comienzo de año, están realizando esta gran labor. Está Luna Gallardo del grado 11B, Alexander Morales del grado 10C y Dana Valentina del grado 9A. Ellos cada uno trajo su emprendimiento. Nos van a comentar cómo fue esta experiencia, cómo ha sido. Buenas tardes, mi nombre es Alexander Morales del grado 10C y mi emprendimiento o la microempresa que yo creí el día de hoy fue las rellenas. Nosotros nos especializamos en, como su nombre lo dice, donas rellenas pero también vendemos roes de rosquillas, con lo que han dicho, y con diferentes coberturas, todo a la elección del cliente. Pues, primeramente agradecer a Dios por la oportunidad de poder estar acá, que aunque la ayuda no nos favoreció, no fue un inconveniente para poder cumplir nuestra meta, que fue la experiencia de poder crear una empresa y de la idea de crear un emprendimiento.

# %%
result
# Out:
# {'text': ' Tres estudiantes que hoy nos ofrecen estos productos, que como dicen las profesoras desde comienzo de año, están realizando esta gran labor. Está Luna Gallardo del grado 11B, Alexander Morales del grado 10C y Dana Valentina del grado 9A. Ellos cada uno trajo su emprendimiento. Nos van a comentar cómo fue esta experiencia, cómo ha sido. Buenas tardes, mi nombre es Alexander Morales del grado 10C y mi emprendimiento o la microempresa que yo creí el día de hoy fue las rellenas. Nosotros nos especializamos en, como su nombre lo dice, donas rellenas pero también vendemos roes de rosquillas, con lo que han dicho, y con diferentes coberturas, todo a la elección del cliente. Pues, primeramente agradecer a Dios por la oportunidad de poder estar acá, que aunque la ayuda no nos favoreció, no fue un inconveniente para poder cumplir nuestra meta, que fue la experiencia de poder crear una empresa y de la idea de crear un emprendimiento.',
#  'segments': [{'id': 0,
#    'seek': 0,
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(result['segments'])[['id','start','end','text']]
# Out:
#     id  start    end                                               text
# 0    0   0.00   5.28   Tres estudiantes que hoy nos ofrecen estos pr...
# 1    1   5.28   9.68   comienzo de año, están realizando esta gran l...
# 2    2   9.68  14.60   Está Luna Gallardo del grado 11B, Alexander M...
# 3    3  14.60  15.60                                          grado 9A.
# 4    4  15.60  17.64            Ellos cada uno trajo su emprendimiento.
# 5    5  17.64  22.56   Nos van a comentar cómo fue esta experiencia,...
# 6    6  22.56  27.72   Buenas tardes, mi nombre es Alexander Morales...
# 7    7  27.72  30.64        que yo creí el día de hoy fue las rellenas.
# 8    8  30.64  34.28   Nosotros nos especializamos en, como su nombr...
# 9    9  34.28  38.32   roes de rosquillas, con lo que han dicho, y c...
# 10  10  38.32  39.32                                       del cliente.
# 11  11  39.32  43.52   Pues, primeramente agradecer a Dios por la op...
# ...
